# %% [markdown]
# # Use Cases Excercise
# ## Document the Notebook Using mark down
# $${\color{red}Senthil Kumar Masanam}$$
# ![](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)

# %% [markdown]
# # Create a volume namely usage_metrics using sql magic command %sql

# %%
# %sql
create volume workspace.volume1.test_usage_metrics

# %% [markdown]
# Task3: Create a child notebook "4_child_nb_dataload" and write code to load data, Using the requests library, perform api call to pull data from "https://public.tableau.com/app/sample-data/mobile_os_usage.csv" into a python variable using the magic command %py and write the data into the created volume "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv" using the above variable.text using the magic command dbutils.fs.put("volume",variable.text,overwrite=True)

# %%
import requests
data = requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
print(data.text)
dbutils.fs.put("/Volumes/workspace/default/volume1/mobile_os_usage.csv", data.text)

# %% [markdown]
# Task5: list the file is created in the given volume or not and do the head of this file using fs magic command %fs

# %%
# %fs ls /Volumes/workspace/default/volume1

# %%
# %python
data = "/Volumes/workspace/default/volume1/mobile_os_usage.csv"
df = spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .load(data)
df.show()
display(df)

# %%
df_clean = (
  df.withColumnRenamed("Mobile Operating System", "Mobile_Operating_System")
    .withColumnRenamed("Percent of Usage", "Percent_of_Usage")
)
df_clean.write.mode("overwrite").saveAsTable("default.mobile_os_usage")
display(sql("select * from default.mobile_os_usage"))

# %%
# %python
def to_uppercase(text):
    return(text.upper())

print(to_uppercase("abc"))

# %%
import pandas as pd
file_path = "/Volumes/workspace/default/volume1/mobile_os_usage.csv"
df = pd.read_csv(file_path)
df

# %%
# %sh
echo "Magic commands tasks completed"
